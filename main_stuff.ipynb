# %% [markdown]
# Let's start here.

# %%
import pandas as pd
import seaborn as sns
import IPython
import numpy as np
import sweetviz as sv

# %%
books_df = pd.read_csv("./data/dataset.csv")
books_df.drop('url', axis = 1, inplace=True)
books_df.drop(books_df.columns[0], axis=1, inplace=True)

# %%
books_df.head(1)
# Out:
#                    title      author  num_reviews  num_ratings  avg_rating  \
# 0  To Kill a Mockingbird  Harper Lee        95178      4751916        4.28
#
#    num_pages  original_publish_year  series  \
# 0        324                   1960    True
#
#                                   genres  \
# 0  ['Classics', 'Fiction', 'Historical']
#
#                                               awards         places  \
# 0  Pulitzer Prize for Fiction (1961), Audie Award...  United States
#
#    awards_count
# 0             4

# %%
# books_df.author.nunique(), books_df.shape
books_df.places.isna().sum()
books_df.places.replace(np.nan, "Unknown")
# Out:
# 0       United States
# 1      United Kingdom
# 2      United Kingdom
# 3       United States
# 4             Unknown
#             ...
# 609     United States
# 610     United States
# 611           Unknown
# 612    United Kingdom
# 613           Unknown
# Name: places, Length: 614, dtype: object

# %%
anaylze_report = sv.analyze(books_df)
anaylze_report.show_html('analyze.html', open_browser = True)
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:01 -> (00:00 left)
# Report analyze.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
books_df.loc[:,['author', 'awards_count']]
# Out:
#                     author  awards_count
# 0               Harper Lee             4
# 1            George Orwell             2
# 2           J.K. Rowling,             27
# 3    F. Scott Fitzgerald,              2
# 4          George Orwell,              2
# ..                     ...           ...
# 609      Madeleine L'Engle             4
# 610       John     Nichols             1
# 611          Mary  Stewart             1
# 612          Russell Hoban             3
# 613         Bruno Schulz,              2
#
# [614 rows x 2 columns]
