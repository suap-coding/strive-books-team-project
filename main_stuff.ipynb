# %% [markdown]
# Let's start here.

# %%
import pandas as pd
import seaborn as sns
import IPython
import numpy as np
import sweetviz as sv

# %%
books_df = pd.read_csv("./data/dataset.csv")

# %%
books_no_url = books_df.drop('url', axis = 1 )

# %%
books_no_url.head()
# Out:
#    Unnamed: 0                                  title                 author  \
# 0           0                  To Kill a Mockingbird             Harper Lee
# 1           1                                   1984          George Orwell
# 2           2  Harry Potter and the Sorcerer's Stone         J.K. Rowling,
# 3           3                       The Great Gatsby  F. Scott Fitzgerald,
# 4           4                            Animal Farm        George Orwell,
#
#    num_reviews  num_ratings  avg_rating  num_pages  original_publish_year  \
# 0        95178      4751916        4.28        324                   1960
# 1        76077      3365418        4.19        237                   1949
# 2       119110      7511380        4.48        309                   1997
# 3        71655      3980916        3.93        200                   1925
# 4        61102      2911765        3.96        141                   1945
#
#    series                                      genres  \
# ...

# %%
anaylze_report = sv.analyze(books_no_url)
anaylze_report.show_html('analyze.html', open_browser = False)
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)Report analyze.html was generated.

# %%
IPython.display.HTML('analyze.html')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-28-173818a475e6> in <module>
# ----> 1 IPython.display.HTML('analyze.html')
#
# ~\anaconda3\envs\wojtek\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, metadata)
#     716         if warn():
#     717             warnings.warn("Consider using IPython.display.IFrame instead")
# --> 718         super(HTML, self).__init__(data=data, url=url, filename=filename, metadata=metadata)
#     719
#     720     def _repr_html_(self):
#
# ~\anaconda3\envs\wojtek\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, metadata)
#     628             self.metadata = {}
#     629
# --> 630         self.reload()
#     631         self._check_data()
#     632
#
# ~\anaconda3\envs\wojtek\lib\site-packages\IPython\core\display.py in reload(self)
# ...

# %%
import pandas_profiling as ProfileReport

# %%
analysis = ProfileReport(books_no_url, title='Pandas Profiling Report', html={'style':{'full_width':True}})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-eb3343493c64> in <module>
# ----> 1 analysis = ProfileReport(books_no_url, title='Pandas Profiling Report', html={'style':{'full_width':True}})
#
# TypeError: 'module' object is not callable
